# %%
from census import Census
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
music_df = pd.read_csv('data.csv')
music_df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
popular_music_df = music_df.sort_values(['popularity'],ascending=False)
popular_music_df = popular_music_df.head(1700)
popular_music_df
# Out:
#         acousticness                        artists  danceability  \
# 20062         0.7210             ['Olivia Rodrigo']         0.585
# 19862         0.2210      ['24kGoldn', 'iann dior']         0.700
# 19866         0.4680              ['Ariana Grande']         0.737
# 19886         0.4010   ['Bad Bunny', 'Jhay Cortez']         0.731
# 19976         0.2120                    ['KAROL G']         0.863
# ...              ...                            ...           ...
# 76138         0.7010                       ['LANY']         0.559
# 38938         0.9370             ['Crafting Audio']         0.107
# 39242         0.0143       ['SAINt JHN', 'Imanbek']         0.769
# 93794         0.1190                       ['jxdn']         0.554
# 126531        0.0378  ['Miley Cyrus', 'Billy Idol']         0.638
#
#         duration_ms  energy  explicit                      id  \
# 20062        242014   0.436         1  7lPN2DXiMsVn7XUKtOW1CS
# ...

# %%
popular_music_df.describe()
# Out:
#        acousticness  danceability    duration_ms       energy     explicit  \
# count   1700.000000   1700.000000    1700.000000  1700.000000  1700.000000
# mean       0.249834      0.652552  209560.248235     0.624530     0.356471
# std        0.263913      0.150587   50121.681609     0.185391     0.479097
# min        0.000010      0.000000   64654.000000     0.000020     0.000000
# 25%        0.037350      0.552750  178867.000000     0.511000     0.000000
# 50%        0.151000      0.669000  205353.500000     0.640000     0.000000
# 75%        0.393000      0.761000  232950.000000     0.762000     1.000000
# max        0.994000      0.980000  536067.000000     0.988000     1.000000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       1700.000000  1700.000000  1700.000000  1700.000000  1700.000000
# mean           0.018313     5.261765     0.169228    -6.797024     0.618235
# ...

# %%
popular_music_df['year'].mode()
# Out:
# 0    2020
# dtype: int64

# %%
popular_music_df['year'].value_counts()
# Out:
# 2020    492
# 2019    254
# 2018    172
# 2017    141
# 2015     65
#        ...
# 1993      2
# 1957      2
# 1974      1
# 1961      1
# 1942      1
# Name: year, Length: 64, dtype: int64

# %%
popular_music_df['key'].value_counts()
# Out:
# 1     201
# 0     198
# 7     164
# 11    152
# 5     151
# 6     145
# 2     141
# 8     129
# 9     128
# 4     127
# 10    119
# 3      45
# Name: key, dtype: int64

# %%
popular_music_df['explicit'].value_counts()
# Out:
# 0    1094
# 1     606
# Name: explicit, dtype: int64
